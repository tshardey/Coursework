# %% [markdown]
# # Iris Dataset
#
# The Iris flower dataset is a multivariate data set.  The dataset consists of 50 samples each of three species of Iris:
# - setosa
# - virginica
# - versicolor
#
# Four features were measured from each sample:
# 1. length of sepal
# 2. width of sepal
# 3. length of petals
# 4. length of sepal

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
#importing the data 
iris_dataset = load_iris()

print("Target names:{}".format(iris_dataset["target_names"]))
print("Feature names:{}".format(iris_dataset["feature_names"]))
print("Shape of data:{}".format(iris_dataset["data"].shape))
print("Shape of target:{}".format(iris_dataset["target"].shape))
# Out:
# Target names:['setosa' 'versicolor' 'virginica']
# Feature names:['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Shape of data:(150, 4)
# Shape of target:(150,)

# %%
# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(iris_dataset["data"], iris_dataset["target"], random_state=0)

print("X_train shape:{}".format(X_train.shape))
print("X_test shape:{}".format(X_test.shape))
print("y_train shape:{}".format(y_train.shape))
print("y_test shape:{}".format(y_test.shape))
# Out:
# X_train shape:(112, 4)
# X_test shape:(38, 4)
# y_train shape:(112,)
# y_test shape:(38,)

# %%
# Creating a dataframe from the X_train data
iris_df = pd.DataFrame(X_train, columns=iris_dataset.feature_names)

# %matplotlib inline
# Creating a scatter matrix from the dataframe colored by y_train
pd.plotting.scatter_matrix(iris_df, c=y_train, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118046ac8>,
# ...
#       dtype=object)

# %% [markdown]
# ## k-nearest neighbor
#
# The KNeighborsClassifier was selected, with n_neighbors=1.
# From the dataset the three three species seem to be fairly well separated.  The k-nearest neighbors will classify new data based on the nearest existing data points, determined by a fixed number (k).  For simplicity 1 was selected for the first pass.

# %%
# Encapsulating the algorithm
knn = KNeighborsClassifier(n_neighbors=1)

# %%
# Fitting the data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# ## Making Predictions

# %%
# Creating a new sample
X_new = np.array([[5, 2.9, 1, 0.2]])
# Predicting the species
prediction = knn.predict(X_new)
print("Prediction:{}".format(prediction))
print("Prediction target name:{}".format(iris_dataset["target_names"][prediction]))
# Out:
# Prediction:[0]
# Prediction target name:['setosa']

# %% [markdown]
# ## Model Evaluation

# %%
# Checking the accuracy score using the test data
print("Test set score:{:.2f}".format(knn.score(X_test, y_test)))
# Out:
# Test set score:0.97
